# %% [markdown]
# <a href="https://colab.research.google.com/github/pierrelouisbescond/medium_articles/blob/main/medium_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing librairies

# %%
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # When is the best day to post an article?
# ## Data Upload

# %%
df = pd.read_excel("/content/drive/MyDrive/Medium/Medium Stats.xlsx", sheet_name="visits")
df
# Out:
#           Date  Visits
# 0   2020-05-09      50
# 1   2020-05-10      59
# 2   2020-05-11      30
# 3   2020-05-12      12
# 4   2020-05-13       5
# ..         ...     ...
# 291 2021-02-24     148
# 292 2021-02-25     138
# 293 2021-02-26     135
# 294 2021-02-27     115
# 295 2021-02-28      86
#
# [296 rows x 2 columns]

# %%
df["article_release"]=~df["Date"].isin(articles_release_dates)

# %%
~df["Date"].isin(articles_release_dates)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 291     True
# 292     True
# 293     True
# 294     True
# 295     True
# Name: Date, Length: 296, dtype: bool

# %%
articles_release_dates = ["2020-05-09", "2020-05-18", "2020-05-22", "2020-05-24", "2020-05-28",
                          "2020-05-31", "2020-06-08", "2020-06-15", "2020-06-22", "2020-07-19",
                          "2020-07-30", "2020-08-24", "2020-10-29", "2020-11-02", "2020-11-25",
                          "2020-12-01", "2020-12-17", "2020-12-21", "2020-12-30", "2021-01-06",
                          "2021-02-01"]

# %%
# We index all dates when an article has been published
df["article_release"] = df["Date"].isin(articles_release_dates) * 1
# We index day+1 and day+2 after an article has been published
df["article_release"] = df["article_release"] + df["article_release"].shift(1, fill_value=0) + df["article_release"].shift(2, fill_value=0)

df
# Out:
#           Date  Visits  article_release
# 0   2020-05-09      50                1
# 1   2020-05-10      59                1
# 2   2020-05-11      30                1
# 3   2020-05-12      12                0
# 4   2020-05-13       5                0
# ..         ...     ...              ...
# 291 2021-02-24     148                0
# 292 2021-02-25     138                0
# 293 2021-02-26     135                0
# 294 2021-02-27     115                0
# 295 2021-02-28      86                0
#
# [296 rows x 3 columns]

# %%
# We calculate the average number of visits, excluding day, day+1 and day+2 after an article was published
mean_without_release = df["Visits"][df["article_release"] == 0].mean()
print ("Mean without articles peaks:", mean_without_release)

# We create a "Visits_norm" column where peaks related to articles' submission are normalized
df["Visits_norm"] = df["Visits"]
df["Visits_norm"][df["article_release"] >= 1] = mean_without_release
df
# Out:
# Mean without articles peaks: 87.52564102564102
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Date  Visits  article_release  Visits_norm
# 0   2020-05-09      50                1    87.525641
# 1   2020-05-10      59                1    87.525641
# 2   2020-05-11      30                1    87.525641
# 3   2020-05-12      12                0    12.000000
# 4   2020-05-13       5                0     5.000000
# ..         ...     ...              ...          ...
# 291 2021-02-24     148                0   148.000000
# 292 2021-02-25     138                0   138.000000
# 293 2021-02-26     135                0   135.000000
# 294 2021-02-27     115                0   115.000000
# 295 2021-02-28      86                0    86.000000
#
# [296 rows x 4 columns]

# %%
# We plot the original and normalized visits numbers per day
fig = go.Figure()
fig.add_trace(go.Scatter(x=df["Date"], y=df.Visits, mode='lines', name='Visits'))
fig.add_trace(go.Scatter(x=df["Date"], y=df.Visits_norm, mode='lines', name='Visits_norm'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f700aa8f-c60d-4d3c-9c0b-f0220e2b6f70" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f700aa8f-c60d-4d3c-9c0b-f0220e2b6f70")) {
#                     Plotly.newPlot(
#                         'f700aa8f-c60d-4d3c-9c0b-f0220e2b6f70',
#                         [{"mode": "lines", "name": "Visits", "type": "scatter", "x": ["2020-05-09T00:00:00", "2020-05-10T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-16T00:00:00", "2020-05-17T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-23T00:00:00", "2020-05-24T00:00:00", "2020-05-25T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-05-30T00:00:00", "2020-05-31T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-06T00:00:00", "2020-06-07T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-13T00:00:00", "2020-06-14T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-20T00:00:00", "2020-06-21T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-27T00:00:00", "2020-06-28T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-03T00:00:00", "2020-07-04T00:00:00", "2020-07-05T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-11T00:00:00", "2020-07-12T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-18T00:00:00", "2020-07-19T00:00:00", "2020-07-20T00:00:00", "2020-07-21T00:00:00", "2020-07-22T00:00:00", "2020-07-23T00:00:00", "2020-07-24T00:00:00", "2020-07-25T00:00:00", "2020-07-26T00:00:00", "2020-07-27T00:00:00", "2020-07-28T00:00:00", "2020-07-29T00:00:00", "2020-07-30T00:00:00", "2020-07-31T00:00:00", "2020-08-01T00:00:00", "2020-08-02T00:00:00", "2020-08-03T00:00:00", "2020-08-04T00:00:00", "2020-08-05T00:00:00", "2020-08-06T00:00:00", "2020-08-07T00:00:00", "2020-08-08T00:00:00", "2020-08-09T00:00:00", "2020-08-10T00:00:00", "2020-08-11T00:00:00", "2020-08-12T00:00:00", "2020-08-13T00:00:00", "2020-08-14T00:00:00", "2020-08-15T00:00:00", "2020-08-16T00:00:00", "2020-08-17T00:00:00", "2020-08-18T00:00:00", "2020-08-19T00:00:00", "2020-08-20T00:00:00", "2020-08-21T00:00:00", "2020-08-22T00:00:00", "2020-08-23T00:00:00", "2020-08-24T00:00:00", "2020-08-25T00:00:00", "2020-08-26T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-29T00:00:00", "2020-08-30T00:00:00", "2020-08-31T00:00:00", "2020-09-01T00:00:00", "2020-09-02T00:00:00", "2020-09-03T00:00:00", "2020-09-04T00:00:00", "2020-09-05T00:00:00", "2020-09-06T00:00:00", "2020-09-07T00:00:00", "2020-09-08T00:00:00", "2020-09-09T00:00:00", "2020-09-10T00:00:00", "2020-09-11T00:00:00", "2020-09-12T00:00:00", "2020-09-13T00:00:00", "2020-09-14T00:00:00", "2020-09-15T00:00:00", "2020-09-16T00:00:00", "2020-09-17T00:00:00", "2020-09-18T00:00:00", "2020-09-19T00:00:00", "2020-09-20T00:00:00", "2020-09-21T00:00:00", "2020-09-22T00:00:00", "2020-09-23T00:00:00", "2020-09-24T00:00:00", "2020-09-25T00:00:00", "2020-09-26T00:00:00", "2020-09-27T00:00:00", "2020-09-28T00:00:00", "2020-09-29T00:00:00", "2020-09-30T00:00:00", "2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "202 ...

# %%
# We extract the number of the weekday numbers and names
df['weekday'] = df['Date'].dt.dayofweek
df['weekday_name'] = df['Date'].dt.day_name()
df
# Out:
#           Date  Visits  article_release  Visits_norm  weekday weekday_name
# 0   2020-05-09      50                1    87.525641        5     Saturday
# 1   2020-05-10      59                1    87.525641        6       Sunday
# 2   2020-05-11      30                1    87.525641        0       Monday
# 3   2020-05-12      12                0    12.000000        1      Tuesday
# 4   2020-05-13       5                0     5.000000        2    Wednesday
# ..         ...     ...              ...          ...      ...          ...
# 291 2021-02-24     148                0   148.000000        2    Wednesday
# 292 2021-02-25     138                0   138.000000        3     Thursday
# 293 2021-02-26     135                0   135.000000        4       Friday
# 294 2021-02-27     115                0   115.000000        5     Saturday
# 295 2021-02-28      86                0    86.000000        6       Sunday
#
# [296 rows x 6 columns]

# %%
# We rank the days per average number of visits (normalized and original values)
df_mean = df.groupby("weekday_name").mean()
df_mean[["Visits_norm", "Visits"]].sort_values(ascending=False, by="Visits_norm")
# Out:
#               Visits_norm      Visits
# weekday_name
# Monday         103.031136  132.214286
# Wednesday       99.650183  120.904762
# Tuesday         96.554945  123.428571
# Thursday        89.885836  115.785714
# Friday          86.766789  106.833333
# Saturday        71.073345   72.302326
# Sunday          66.607036   64.930233

# %%
# We diplay the visits per day thanks to box-plots
fig = px.box(df.sort_values(by="weekday"), y="Visits_norm", x="weekday_name")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d0c444df-fd5a-46de-8e28-b7e099fd2c21" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d0c444df-fd5a-46de-8e28-b7e099fd2c21")) {
#                     Plotly.newPlot(
#                         'd0c444df-fd5a-46de-8e28-b7e099fd2c21',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "weekday_name=%{x}<br>Visits_norm=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Monday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Tuesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Wednesday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Thursday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Friday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Saturday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday", "Sunday"], "x0": " ", "xaxis": "x", "y": [121.0, 87.52564102564102, 87.52564102564102, 87.52564102564102, 134.0, 87.52564102564102, 125.0, 68.0, 146.0, 32.0, 146.0, 145.0, 87.52564102564102, 87.52564102564102, 120.0, 125.0, 67.0, 79.0, 47.0, 87.52564102564102, 165.0, 71.0, 87.52564102564102, 152.0, 87.52564102564102, 73.0, 102.0, 87.52564102564102, 67.0, 137.0, 121.0, 42.0, 125.0, 161.0, 87.5256410256410 ...
#                         {"boxmode": "group", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "c

# %% [markdown]
# ## The "T-Test" or "Student T-Test"

# %%
import scipy.stats as stats

# %%
population_1 = np.random.normal(30, 5, 1000)
print("Population 1 Mean: {:.2f} and Standard Deviation: {:.2f}".format(population_1.mean(), population_1.std()))

sample_1 = np.random.choice(population_1, 100)
sample_2 = np.random.choice(population_1, 100)

print("Sample 1 Mean: {:.2f} and Standard Deviation: {:.2f}".format(sample_1.mean(), sample_1.std()))
print("Sample 2 Mean: {:.2f} and Standard Deviation: {:.2f}".format(sample_2.mean(), sample_2.std()))
# Out:
# Population 1 Mean: 30.23 and Standard Deviation: 4.89
# Sample 1 Mean: 31.30 and Standard Deviation: 4.54
# Sample 2 Mean: 31.00 and Standard Deviation: 4.64

# %%
population_2 = np.random.normal(28, 3, 1000)
print("Population 2 Mean: {:.2f} and Standard Deviation: {:.2f}".format(population_2.mean(), population_2.std()))

sample_3 = np.random.choice(population_2, 100)
print("Sample 3 Mean: {:.2f} and Standard Deviation: {:.2f}".format(sample_3.mean(), sample_3.std()))
# Out:
# Population 2 Mean: 27.92 and Standard Deviation: 3.02
# Sample 3 Mean: 28.50 and Standard Deviation: 2.99

# %%
p_value = stats.ttest_ind(sample_1, sample_2)[1]
print("Sample 1 Vs Sample 2 p_value: {:.4f}".format(p_value))
p_value = stats.ttest_ind(sample_1, sample_3)[1]
print("Sample 1 Vs Sample 3 p_value: {:.4f}".format(p_value))
p_value = stats.ttest_ind(sample_2, sample_3)[1]
print("Sample 2 Vs Sample 3 p_value: {:.4f}".format(p_value))
# Out:
# Sample 1 Vs Sample 2 p_value: 0.6505
# Sample 1 Vs Sample 3 p_value: 0.0000
# Sample 2 Vs Sample 3 p_value: 0.0000

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=sample_1, marker_color='#5A9EFF', name="Sample 1"))
fig.add_trace(go.Histogram(x=sample_2, marker_color='#3282FF', name="Sample 2"))
fig.add_trace(go.Histogram(x=sample_3, marker_color='#14C82E', name="Sample 3"))
fig.update_layout(bargap=0.1, bargroupgap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="376b000f-e93d-49fd-9c04-5d46a3dd7318" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("376b000f-e93d-49fd-9c04-5d46a3dd7318")) {
#                     Plotly.newPlot(
#                         '376b000f-e93d-49fd-9c04-5d46a3dd7318',
#                         [{"marker": {"color": "#5A9EFF"}, "name": "Sample 1", "type": "histogram", "x": [34.11214299567657, 30.38472621656625, 37.08035607966429, 29.532549491771835, 30.10218961555739, 26.4035021813457, 32.19930083598672, 33.8921968969655, 14.640055475012637, 29.899057250858455, 31.00890268498191, 38.46486307895845, 34.012157108865416, 31.562907281556242, 35.78248465829475, 34.00357593594709, 40.559272837603366,
"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.55555555555555

# %% [markdown]
# ## The statistical differences between the weekdays

# %%
weekdays_name = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# We create a DataFrame where both axis corresponds to the weekdays names
ttest_matrix = pd.DataFrame(index=weekdays_name, columns=weekdays_name)

# For every possibility of days couple , we calculate the T-Test
for x in np.arange(0, 7, 1):
  for y in np.arange(0, 7, 1):
    if x < y:
      p_value = stats.ttest_ind(df["Visits_norm"][df["weekday"] == x], df["Visits_norm"][df["weekday"] == y])[1]
      ttest_matrix.loc[weekdays_name[y], weekdays_name[x]] = p_value

ttest_matrix = ttest_matrix.mask(ttest_matrix <= 0.05, "Different!")
ttest_matrix = ttest_matrix.fillna("")
ttest_matrix
# Out:
#                Monday     Tuesday   Wednesday  ...      Friday  Saturday Sunday
# Monday                                         ...
# Tuesday      0.389521                          ...
# Wednesday    0.664696    0.693737              ...
# Thursday    0.0935077    0.395472    0.230442  ...
# Friday     Different!    0.201553    0.106077  ...
# Saturday   Different!  Different!  Different!  ...  Different!
# Sunday     Different!  Different!  Different!  ...  Different!  0.499288
#
# [7 rows x 7 columns]

# %% [markdown]
# ## How many visits, claps or reading time do you need to reach 1000$?

# %%
df_articles = pd.read_excel("/content/drive/MyDrive/Medium/Medium Stats.xlsx", sheet_name="earnings", usecols="A:G")
df_articles
# Out:
#                                          Article Name  Views  ...  Claps  Earning
# 0   XAI — Build your own deep-learning interpretat...    240  ...     17     1.55
# 1   Data Science 101: Start with Pandas, Scikit-Le...    344  ...     16     2.86
# 2        Better visualizing tensors thanks to cities!    182  ...     11     1.18
# 3   Help Santa optimize his Christmas run with Goo...    788  ...     89    11.34
# 4            Four Ultimate Mail Management Principles    611  ...      6     0.14
# 5   Lobe, Microsoft’s No-Code Computer Vision Soft...    361  ...     27     1.57
# 6   Employees’ Attrition — How Catboost and Shap c...    549  ...     24     8.91
# 7   Beyond “classic” PCA: Functional Principal Com...   3069  ...     47    25.23
# 8   AI in Industry: How a Maintenance Routine ruin...    576  ...     32     7.13
# 9   Don’t Forget the Big Green Button… and Other E...    328  ...     19     3.59
# 10  AI in Industry: Why you should synchronize fea...    428  ...     41     6.67
# 11  AI in Industry: How to use sensors’ accuracy t...    369  ...     44     3.08
# 12       Cyclical features encoding, it’s about time!   4858  ...     37    46.83
# 13  Principal Components Analysis (PCA), Fundament...   1322  ...     67    13.10
# 14  The robustness of Machine Learning algorithms ...    958  ...      2     8.87
# 15  Build a Machine Learning simulation tool with ...   6247  ...    110    50.74
# 16  Solving non-linear problems with genetic algor...    597  ...      4     2.78
# 17  Solving non-linear problems with genetic algor...   1094  ...      7     7.16
#
# [18 rows x 7 columns]

# %%
df_articles._get_numeric_data().sum()
# Out:
# Views           22921.00
# Reads            9495.00
# Reading Time     4976.00
# Fans              168.00
# Claps             600.00
# Earning           202.73
# dtype: float64

# %%
corr_mat = df_articles[["Views", "Reads", "Reading Time", "Fans", "Claps", "Earning"]].corr()
corr_mat[["Earning"]][corr_mat["Earning"] < 1]
# Out:
#                Earning
# Views         0.982667
# Reads         0.973393
# Reading Time  0.996033
# Fans          0.940996
# Claps         0.628918

# %%
dollar_per_hour = df_articles["Earning"].sum() / df_articles["Reading Time"].sum()
round(dollar_per_hour, 3)
# Out:
# 0.041

# %%
10 / dollar_per_hour
# Out:
# 245.44961278547825
